# %%
import tensorflow as tf
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense,RepeatVector
from keras.layers import Flatten
from keras.layers import TimeDistributed

# %% [markdown]
# ## Data Loading

# %%
# USE THIS PATH FOR WINDOWS
#biomass_history = pd.read_csv('dataset\Biomass_History.csv')
# PATH FOR LINUX
biomass_history = pd.read_csv('dataset/Biomass_History.csv')

# %%
biomass_history.head(20)
# Out:
#     Index  Latitude  Longitude        2010        2011        2012  \
# 0       0  24.66818   71.33144    8.475744    8.868568    9.202181
# 1       1  24.66818   71.41106   24.029778   28.551348   25.866415
# 2       2  24.66818   71.49069   44.831635   66.111168   56.982258
# 3       3  24.66818   71.57031   59.974419   80.821304   78.956543
# 4       4  24.66818   71.64994   14.653370   19.327524   21.928144
# 5       5  24.66818   71.72956   17.416639   35.811001   26.003826
# 6       6  24.66818   71.80919   23.568657   37.371216   38.298550
# 7       7  24.66818   71.88882   48.345234   91.215836   91.906342
# 8       8  24.66818   71.96844   58.784283   50.206898   60.707321
# 9       9  24.66818   72.04807   67.907379   68.375999   87.026680
# 10     10  24.66818   72.12769    8.916524   16.679886   21.618805
# 11     11  24.66818   72.20732    3.416374    2.891346    3.826416
# 12     12  24.66818   72.28694    2.298106    2.165051    1.780242
# ...

# %%
biomass_history.describe()
# Out:
#              Index     Latitude    Longitude         2010         2011  \
# count  2418.000000  2418.000000  2418.000000  2418.000000  2418.000000
# mean   1208.500000    22.506537    71.826215   144.401424   150.860247
# std     698.160798     1.034936     1.389804   146.506351   142.264612
# min       0.000000    20.154560    68.624190     0.000167     0.000433
# 25%     604.250000    21.685970    70.774060    23.449163    25.576084
# 50%    1208.500000    22.491970    71.888820   112.298855   126.291077
# 75%    1812.750000    23.297970    73.003570   207.689327   226.197079
# max    2417.000000    24.668180    74.436820   883.691711   771.061646
#
#               2012         2013         2014         2015         2016  \
# count  2418.000000  2418.000000  2418.000000  2418.000000  2418.000000
# mean    109.468899   161.886430   157.954024   132.898633   113.089323
# std     110.249714   180.337708   139.870466   129.689111   102.092570
# ...

# %%
biomass_history.shape
# Out:
# (2418, 11)

# %%
tf.keras.layers.Conv1D
model = Sequential()
# Out:
# 2023-08-19 20:30:42.307058: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4279 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
